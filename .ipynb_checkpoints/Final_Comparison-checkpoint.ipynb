# %%
import pandas as pd

momentum = pd.read_csv("metrics_momentum.csv", index_col=0)
sma = pd.read_csv("metrics_sma.csv", index_col=0)
vol_target = pd.read_csv("metrics_voltarget.csv", index_col=0)
mean_rev = pd.read_csv("metrics_meanreversion.csv", index_col=0)
bandh = pd.read_csv("metrics_bandh.csv", index_col=0)
pd.DataFrame({
    "Buy And Hold":bandh.iloc[:,0],
    "Momentum (monthly)": momentum.iloc[:, 0],
    "SMA Crossover": sma.iloc[:, 0],
    "Volatility Target": vol_target.iloc[:, 0],
    "Mean Reversion": mean_rev.iloc[:, 0]
})
# Out:
#                          Buy And Hold Momentum (monthly) SMA Crossover  \
# Cumulative return             161.65%            370.33%       172.24%
# Annualized return              17.66%             29.44%        18.46%
# Mean return                     0.06%              2.15%         0.07%
# Period volatility               2.83%              7.98%         2.16%
# Annual volatility              44.88%             27.63%        34.34%
# Winrate                        51.28%             45.83%        38.05%
# Sharpe Ratio                   0.3936             1.0655        0.5376
# Max Drawdown                  -75.95%            -38.12%       -48.00%
# Sortino                        0.4594             1.0623        0.6093
# Calmar                         0.2326             0.7722        0.3846
# Historic VaR                   -3.76%             -7.44%        -2.93%
# Conditional Historic VaR       -6.32%            -16.42%        -4.99%
#
# ...
